# %% [markdown]
# # Mejores canciones latinas
#
# Segun un tipo de internet

# %%
import pandas

# %%
result = pandas.read_html('https://nicolasramospintado.wordpress.com/2010/02/26/las-100-mejores-canciones-latinas-de-la-historia-the-hot-latin-songs/')

# %%
type(result)
# Out:
# list

# %%
songs = result[0]
songs
# Out:
#        0    1                    2  \
# 0     Nº   Nº               Canión
# 1    NaN  NaN                  NaN
# 2      1    1    GRACIAS A LA VIDA
# 3    NaN  NaN                  NaN
# 4      2    *            DESPACITO
# ..   ...  ...                  ...
# 115  106  106  ABRAZAME MUY FUERTE
# 116  107  107        LATINOAMERICA
# 117  108  108           CONCIENCIA
# 118  109  109         BACHATA ROSA
# 119  110  110               SE FUE
#
#                                               3              4  \
# 0                                    Interprtes        Autores
# 1                                           NaN            NaN
# 2                                 VIOLETA PARRA  Violeta Parra
# 3                                           NaN            NaN
# 4    LUIS FONSI & DADDY YANKE FT. JUSTIN BIEBER     Luis Fonsi
# ..                                          ...            ...
# 115                                Juan Gabriel            NaN
# ...

# %%
songs.columns = songs.iloc[0]
songs
# Out:
# 0     Nº   Nº               Canión  \
# 0     Nº   Nº               Canión
# 1    NaN  NaN                  NaN
# 2      1    1    GRACIAS A LA VIDA
# 3    NaN  NaN                  NaN
# 4      2    *            DESPACITO
# ..   ...  ...                  ...
# 115  106  106  ABRAZAME MUY FUERTE
# 116  107  107        LATINOAMERICA
# 117  108  108           CONCIENCIA
# 118  109  109         BACHATA ROSA
# 119  110  110               SE FUE
#
# 0                                    Interprtes        Autores  \
# 0                                    Interprtes        Autores
# 1                                           NaN            NaN
# 2                                 VIOLETA PARRA  Violeta Parra
# 3                                           NaN            NaN
# 4    LUIS FONSI & DADDY YANKE FT. JUSTIN BIEBER     Luis Fonsi
# ..                                          ...            ...
# 115                                Juan Gabriel            NaN
# ...

# %%
songs['Interprtes']
# Out:
# 0                                      Interprtes
# 1                                             NaN
# 2                                   VIOLETA PARRA
# 3                                             NaN
# 4      LUIS FONSI & DADDY YANKE FT. JUSTIN BIEBER
#                           ...
# 115                                  Juan Gabriel
# 116                                      Calle 13
# 117                           Gilberto Santa Rosa
# 118                              Juan Luis Guerra
# 119                                 Laura Pausini
# Name: Interprtes, Length: 120, dtype: object

# %%
type (songs)
# Out:
# pandas.core.frame.DataFrame

# %%
songs.shape
# Out:
# (120, 7)

# %%
songs = songs.iloc[1:]
songs
# Out:
# 0     Nº   Nº               Canión  \
# 1    NaN  NaN                  NaN
# 2      1    1    GRACIAS A LA VIDA
# 3    NaN  NaN                  NaN
# 4      2    *            DESPACITO
# 5    NaN  NaN                  NaN
# ..   ...  ...                  ...
# 115  106  106  ABRAZAME MUY FUERTE
# 116  107  107        LATINOAMERICA
# 117  108  108           CONCIENCIA
# 118  109  109         BACHATA ROSA
# 119  110  110               SE FUE
#
# 0                                    Interprtes        Autores  \
# 1                                           NaN            NaN
# 2                                 VIOLETA PARRA  Violeta Parra
# 3                                           NaN            NaN
# 4    LUIS FONSI & DADDY YANKE FT. JUSTIN BIEBER     Luis Fonsi
# 5                                           NaN            NaN
# ..                                          ...            ...
# 115                                Juan Gabriel            NaN
# ...

# %%
songs.columns = ['position', 'to_remove', 'name', 'singers', 'authors', 'country', 'year']
songs
# Out:
#     position to_remove                 name  \
# 1        NaN       NaN                  NaN
# 2          1         1    GRACIAS A LA VIDA
# 3        NaN       NaN                  NaN
# 4          2         *            DESPACITO
# 5        NaN       NaN                  NaN
# ..       ...       ...                  ...
# 115      106       106  ABRAZAME MUY FUERTE
# 116      107       107        LATINOAMERICA
# 117      108       108           CONCIENCIA
# 118      109       109         BACHATA ROSA
# 119      110       110               SE FUE
#
#                                         singers        authors  \
# 1                                           NaN            NaN
# 2                                 VIOLETA PARRA  Violeta Parra
# 3                                           NaN            NaN
# 4    LUIS FONSI & DADDY YANKE FT. JUSTIN BIEBER     Luis Fonsi
# 5                                           NaN            NaN
# ...

# %%
songs = songs.drop('to_remove', axis='columns')
songs
# Out:
#     position                 name                                     singers  \
# 1        NaN                  NaN                                         NaN
# 2          1    GRACIAS A LA VIDA                               VIOLETA PARRA
# 3        NaN                  NaN                                         NaN
# 4          2            DESPACITO  LUIS FONSI & DADDY YANKE FT. JUSTIN BIEBER
# 5        NaN                  NaN                                         NaN
# ..       ...                  ...                                         ...
# 115      106  ABRAZAME MUY FUERTE                                Juan Gabriel
# 116      107        LATINOAMERICA                                    Calle 13
# 117      108           CONCIENCIA                         Gilberto Santa Rosa
# 118      109         BACHATA ROSA                            Juan Luis Guerra
# 119      110               SE FUE                               Laura Pausini
#
# ...

# %%
songs = songs.dropna(subset=['name'])
songs
# Out:
#     position                 name  \
# 2          1    GRACIAS A LA VIDA
# 4          2            DESPACITO
# 6          3  LA PALOMA (NO MORE)
# 8          4       BENDITA TU LUZ
# 10         5         BESAME MUCHO
# ..       ...                  ...
# 115      106  ABRAZAME MUY FUERTE
# 116      107        LATINOAMERICA
# 117      108           CONCIENCIA
# 118      109         BACHATA ROSA
# 119      110               SE FUE
#
#                                               singers  \
# 2                                       VIOLETA PARRA
# 4          LUIS FONSI & DADDY YANKE FT. JUSTIN BIEBER
# 6    PLACIDO DOMINGO / ELVIS PRESLEY / JULIO IGLESIAS
# 8                                                MANÁ
# 10                                       LUCHO GATICA
# ..                                                ...
# 115                                      Juan Gabriel
# 116                                          Calle 13
# 117                               Gilberto Santa Rosa
# ...

# %%
countries = {'Aergentina': 'Argentina',
             'Artgentina': 'Argentina',
             'Brasíl': 'Brasil',
             'México': 'Mexico',
             'República Dominicána': 'República Dominicana'}
songs = songs.copy()
songs['country'] = songs['country'].replace(countries)

# %%
songs['country'].drop_duplicates().sort_values()
# Out:
# 12                Argentina
# 14                   Brasil
# 2                     Chile
# 22                 Colombia
# 64            Colombia/Cuba
# 18                     Cuba
# 6                    España
# 119                  Italia
# 8                    Mexico
# 10            Mexico/España
# 47                Nicaragua
# 21                   Panamá
# 68                     Perú
# 4               Puerto Rico
# 103    República Dominicana
# 44                  Uruguay
# 100               Venezuela
# 45                      NaN
# Name: country, dtype: object

# %%
songs
# Out:
# country
# España                  23
# Mexico                  19
# Argentina               17
# Cuba                     6
# Colombia                 4
# Brasil                   3
# Puerto Rico              2
# Panamá                   2
# República Dominicana     2
# Chile                    2
# dtype: int64

# %%
songs.groupby('country').size().sort_values(ascending=False).head(10).plot(kind='pie')

# %%
songs.groupby('country').size().sort_values(ascending=False).head(10)
# Out:
# country
# España                  23
# Mexico                  19
# Argentina               17
# Cuba                     6
# Colombia                 4
# Brasil                   3
# Puerto Rico              2
# Panamá                   2
# República Dominicana     2
# Chile                    2
# dtype: int64

# %%
songs.groupby('country').size().sort_values(ascending=False).head(10).plot(kind='bar')

# %% [raw]
# top_countries = songs.groupby('country').size().sort_values(ascending=False).head()
# top_countries

# %%
top_countries.plot();

# %%
country_names = top_countries.index.tolist()
country_names
# Out:
# ['España',
#  'Mexico',
#  'Argentina',
#  'Cuba',
#  'Colombia',
#  'Brasil',
#  'Puerto Rico',
#  'Panamá',
#  'República Dominicana',
#  'Chile']

# %%
country_num_songs = top_countries.values.tolist()
country_num_songs
# Out:
# [23, 19, 17, 6, 4, 3, 2, 2, 2, 2]

# %%
country_num_songs_josego = [2, 19, 17, 16, 4, 13, 12, 16, 12, 2]

# %%
from matplotlib import pyplot

pyplot.plot(country_names, country_num_songs, country_num_songs_josego)
pyplot.title('Top 10 paises de musica latina')
pyplot.xlabel('Paises')
pyplot.ylabel('Numero de canciones')
# Out:
# Text(0, 0.5, 'Numero de canciones')
